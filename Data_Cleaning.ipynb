# %%
#Import Libs
import pandas as pd
import numpy as np
import gzip

# %%
#Import the data 

movie_df = pd.read_csv('/Users/markdetiberiis/MovieMonths/all_movie_info.csv')

# %%
#Show the data 
movie_df.head()

# %%
#movie_df[(movie_df['worldwide'] > 4 & (movie_df['review_count'] > 100))].sort_values(by = ['rating'], ascending = False)

# %%
#Sort the values by most profit

movie_df.sort_values('worldwide_gross',ascending = False).head(25)

#I think the error is coming from budgets and profits not being dtype int and/or having '$'

movie_df.dtypes
# Out:
# Unnamed: 0             int64
# tconst                object
# primary_title         object
# runtime_minutes      float64
# genres                object
# averagerating        float64
# numvotes               int64
# id                     int64
# release_date          object
# production_budget     object
# domestic_gross        object
# worldwide_gross       object
# dtype: object

# %%
#Need to remove '$' from production_budget, domestic_gross, and worldwide_gross values

#try chaning to a string first 
movie_df['production_budget'] = movie_df['production_budget'].astype(str, copy = True)

# %%
#movie_df.dtypes

# %%
#should work if production_budget was a string
#making prod_budget a string

movie_df['production_budget'] = movie_df['production_budget'].astype(str)

# %%
df_obj = movie_df.select_dtypes(['object'])

# %%
#Get rid of all the '$'

movie_df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip('$'))

# %%
#Make sure all '$' are gone 

movie_df.head()
# Out:
#    Unnamed: 0     tconst  primary_title  runtime_minutes  \
# 0           0  tt0249516     Foodfight!             91.0
# 1           1  tt0326592  The Overnight             88.0
# 2           2  tt3844362  The Overnight             79.0
# 3           3  tt0337692    On the Road            124.0
# 4           4  tt4339118    On the Road             89.0
#
#                     genres  averagerating  numvotes  id  release_date  \
# 0  Action,Animation,Comedy            1.9      8248  26  Dec 31, 2012
# 1                      NaN            7.5        24  21  Jun 19, 2015
# 2           Comedy,Mystery            6.1     14828  21  Jun 19, 2015
# 3  Adventure,Drama,Romance            6.1     37886  17  Mar 22, 2013
# 4                    Drama            6.0         6  17  Mar 22, 2013
#
#   production_budget domestic_gross worldwide_gross
# 0        45,000,000              0          73,706
# 1           200,000      1,109,808       1,165,996
# ...

# %%
#changing production_budget to float 
movie_df['production_budget'] = movie_df['production_budget'].astype(float)
movie_df['worldwide_gross'] = movie_df['worldwide_gross'].astype(float)
movie_df['domestic_gross'] = movie_df['domestic_gross'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-c58aa958ba52> in <module>
#       1 #changing production_budget to float
# ----> 2 movie_df['production_budget'] = movie_df['production_budget'].astype(float)
#       3 movie_df['worldwide_gross'] = movie_df['worldwide_gross'].astype(float)
#       4 movie_df['domestic_gross'] = movie_df['domestic_gross'].astype(float)
#       5
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
# ...

# %%
#get rid of all ','

movie_df['production_budget']=movie_df['production_budget'].str.replace(',','')
movie_df['worldwide_gross']=movie_df['worldwide_gross'].str.replace(',','')
movie_df['domestic_gross']=movie_df['domestic_gross'].str.replace(',','')

# %%
#See how it looks 

movie_df.head()
# Out:
#    Unnamed: 0     tconst  primary_title  runtime_minutes  \
# 0           0  tt0249516     Foodfight!             91.0
# 1           1  tt0326592  The Overnight             88.0
# 2           2  tt3844362  The Overnight             79.0
# 3           3  tt0337692    On the Road            124.0
# 4           4  tt4339118    On the Road             89.0
#
#                     genres  averagerating  numvotes  id  release_date  \
# 0  Action,Animation,Comedy            1.9      8248  26  Dec 31, 2012
# 1                      NaN            7.5        24  21  Jun 19, 2015
# 2           Comedy,Mystery            6.1     14828  21  Jun 19, 2015
# 3  Adventure,Drama,Romance            6.1     37886  17  Mar 22, 2013
# 4                    Drama            6.0         6  17  Mar 22, 2013
#
#   production_budget domestic_gross worldwide_gross
# 0          45000000              0           73706
# 1            200000        1109808         1165996
# ...

# %%
#Show highest production_budget

movie_df.sort_values('production_budget',ascending = False).head()
# Out:
#       Unnamed: 0     tconst      primary_title  runtime_minutes  \
# 148          148  tt0955308         Robin Hood            140.0
# 154          154  tt6858500         Robin Hood              NaN
# 152          152  tt4532826         Robin Hood            116.0
# 2033        2033  tt2452042  The Peanuts Movie             88.0
# 150          150  tt2363363         Robin Hood             92.0
#
#                           genres  averagerating  numvotes  id  release_date  \
# 148       Action,Adventure,Drama            6.6    239480   9  Nov 21, 2018
# 154                          NaN            7.6         5   9  Nov 21, 2018
# 152    Action,Adventure,Thriller            5.3     41588   9  Nov 21, 2018
# 2033  Adventure,Animation,Comedy            7.1     39149   7   Nov 6, 2015
# 150                 Action,Drama            6.3        78   9  Nov 21, 2018
#
#      production_budget domestic_gross worldwide_gross
# 148           99000000       30824628        84747441
# ...

# %%
#Show highest domestic_gross

movie_df.sort_values('domestic_gross',ascending = False).head()
# Out:
#       Unnamed: 0     tconst       primary_title  runtime_minutes  \
# 2604        2604  tt4575576   Christopher Robin            104.0
# 422          422  tt3985956            Hercules            112.0
# 420          420  tt1267297            Hercules             98.0
# 1902        1902  tt2302755  Olympus Has Fallen            119.0
# 174          174  tt0990407    The Green Hornet            119.0
#
#                           genres  averagerating  numvotes  id  release_date  \
# 2604  Adventure,Animation,Comedy            7.3     52737  43   Aug 3, 2018
# 422                       Comedy            6.2        72   8  Jun 13, 1997
# 420     Action,Adventure,Fantasy            6.0    137287   8  Jun 13, 1997
# 1902             Action,Thriller            6.5    235443   9  Mar 22, 2013
# 174          Action,Comedy,Crime            5.8    148622  29  Jan 14, 2011
#
#      production_budget domestic_gross worldwide_gross
# 2604          75000000       99215042       197504758
# ...

# %%
#Show highest worldwide_gross

movie_df.sort_values('worldwide_gross',ascending = False).head()
# Out:
#       Unnamed: 0     tconst               primary_title  runtime_minutes  \
# 900          900  tt1591095                   Insidious            103.0
# 1956        1956  tt2352196  Thank You for Your Service             88.0
# 1957        1957  tt2776878  Thank You for Your Service            109.0
# 1879        1879  tt2274648                     Hellboy            120.0
# 1730        1730  tt2121250                       Alpha            116.0
#
#                         genres  averagerating  numvotes  id  release_date  \
# 900    Horror,Mystery,Thriller            6.9    254197  63   Apr 1, 2011
# 1956         Documentary,Drama            7.7        74  48  Oct 27, 2017
# 1957       Biography,Drama,War            6.5     10006  48  Oct 27, 2017
# 1879  Action,Adventure,Fantasy            5.4     19534  84   Apr 2, 2004
# 1730                     Crime            5.5       102  79  Aug 17, 2018
#
#      production_budget domestic_gross worldwide_gross
# ...

# %%
#I want to leaving the month date and year in seperate columns

movie_df[['release_month','release_day','release_year']] = movie_df.release_date.str.split(expand=True)

# %%
#get rid of the ',' in release_day

movie_df['release_day']=movie_df['release_day'].str.replace(',','')

# %%
movie_df.head()
# Out:
#    Unnamed: 0     tconst  primary_title  runtime_minutes  \
# 0           0  tt0249516     Foodfight!             91.0
# 1           1  tt0326592  The Overnight             88.0
# 2           2  tt3844362  The Overnight             79.0
# 3           3  tt0337692    On the Road            124.0
# 4           4  tt4339118    On the Road             89.0
#
#                     genres  averagerating  numvotes  id  release_date  \
# 0  Action,Animation,Comedy            1.9      8248  26  Dec 31, 2012
# 1                      NaN            7.5        24  21  Jun 19, 2015
# 2           Comedy,Mystery            6.1     14828  21  Jun 19, 2015
# 3  Adventure,Drama,Romance            6.1     37886  17  Mar 22, 2013
# 4                    Drama            6.0         6  17  Mar 22, 2013
#
#   production_budget domestic_gross worldwide_gross release_month release_day  \
# 0          45000000              0           73706           Dec          31
# ...

# %%
movie_df.drop(['release_date'], axis = 1, inplace = True)

# %%
movie_df.to_csv('/Users/markdetiberiis/MovieMonths/clean_movie_info.csv')

# %%
movie_df.head()
# Out:
#    Unnamed: 0     tconst  primary_title  runtime_minutes  \
# 0           0  tt0249516     Foodfight!             91.0
# 1           1  tt0326592  The Overnight             88.0
# 2           2  tt3844362  The Overnight             79.0
# 3           3  tt0337692    On the Road            124.0
# 4           4  tt4339118    On the Road             89.0
#
#                     genres  averagerating  numvotes  id production_budget  \
# 0  Action,Animation,Comedy            1.9      8248  26          45000000
# 1                      NaN            7.5        24  21            200000
# 2           Comedy,Mystery            6.1     14828  21            200000
# 3  Adventure,Drama,Romance            6.1     37886  17          25000000
# 4                    Drama            6.0         6  17          25000000
#
#   domestic_gross worldwide_gross release_month release_day release_year
# 0              0           73706           Dec          31         2012
# ...

# %%
#replace the spaces in title with _ so i can insert into the revfiews url 

#movie_df['primary_title']= movie_df['primary_title'].str.replace(' ','_')
movie_df['primary_title']= movie_df['primary_title'].str.replace('.','')
movie_df['primary_title']= movie_df['primary_title'].str.replace(',','')

# %%
movie_df['primary_title']= movie_df['primary_title'].str.replace(':','')
movie_df['primary_title']= movie_df['primary_title'].str.replace(',','')

# %%
movie_df['primary_title']= movie_df['primary_title'].str.replace("'","")

# %%
movie_df['primary_title']= movie_df['primary_title'].str.replace("/","")
movie_df['primary_title']= movie_df['primary_title'].str.replace("!","")

# %%
movie_df.head()
# Out:
#    Unnamed: 0     tconst  primary_title  runtime_minutes  \
# 0           0  tt0249516     Foodfight!             91.0
# 1           1  tt0326592  The_Overnight             88.0
# 2           2  tt3844362  The_Overnight             79.0
# 3           3  tt0337692    On_the_Road            124.0
# 4           4  tt4339118    On_the_Road             89.0
#
#                     genres  averagerating  numvotes  id production_budget  \
# 0  Action,Animation,Comedy            1.9      8248  26          45000000
# 1                      NaN            7.5        24  21            200000
# 2           Comedy,Mystery            6.1     14828  21            200000
# 3  Adventure,Drama,Romance            6.1     37886  17          25000000
# 4                    Drama            6.0         6  17          25000000
#
#   domestic_gross worldwide_gross release_month release_day release_year
# 0              0           73706           Dec          31         2012
# ...

# %%
movie_df['primary_title'].to_csv('/Users/markdetiberiis/MovieMonths/movie_titles.csv', index=False)

# %%
movie_df['primary_title'].nunique()
# Out:
# 2126

# %%
movie_df.to_csv('/Users/markdetiberiis/MovieMonths/movie_df.csv')
