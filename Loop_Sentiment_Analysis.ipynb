# %%
#Import everything 

import pandas as pd
import numpy as np
import requests
import json
from bs4 import BeautifulSoup
import csv

import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
f = open('/Users/markdetiberiis/MovieMonths/movie_titles.csv')
csv_f = csv.reader(f)

# %%
with open('/Users/markdetiberiis/MovieMonths/movie_titles.csv', newline='') as f:
    reader = csv.reader(f)
    titles = list(reader)

titles
# Out:
# [['primary_title'],
#  ['Foodfight'],
#  ['The_Overnight'],
#  ['The_Overnight'],
#  ['On_the_Road'],
#  ['On_the_Road'],
#  ['On_the_Road'],
#  ['The_Secret_Life_of_Walter_Mitty'],
#  ['A_Walk_Among_the_Tombstones'],
#  ['Jurassic_World'],
#  ['The_Rum_Diary'],
#  ['The_Three_Stooges'],
#  ['Andersons_Cross'],
#  ['Tangled'],
#  ['John_Carter'],
#  ['Action_Jackson'],
#  ['Dinner_for_Schmucks'],
#  ['The_A-Team'],
#  ['The_Possession'],
#  ['Real_Steel'],
#  ['The_Giver'],
#  ['Toy_Story_3'],
#  ['Alita_Battle_Angel'],
#  ['Lincoln'],
#  ['Before_We_Go'],
#  ['Before_We_Go'],
#  ['The_History_of_Love'],
#  ['Shazam'],
#  ['Puss_in_Boots'],
#  ['Wonder_Woman'],
#  ['Wonder_Woman'],
#  ['Wonder_Woman'],
#  ['42'],
#  ['Life_of_Pi'],
#  ['The_Crazies'],
#  ['The_Equalizer'],
#  ['Captain_America_The_First_Avenger'],
#  ['Sin_City_A_Dame_to_Kill_For'],
#  ['House_at_the_End_of_the_Drive'],
#  ['Piranha_3D'],
#  ['Margaret'],
#  ['Ex_Machina'],
#  ['Tower_Heist'],
#  ['The_Smurfs'],
# ...

# %%
#need to continue on status cude 500 as werll as 404
R = requests.get('https://www.rottentomatoes.com/m/5050')
R.status_code
# Out:
# 500

# %%
movie_url = []

for title in new_list:
    movie_url.append('https://www.rottentomatoes.com/m/{}'.format(title))

# %%
movie_url
# Out:
# ['https://www.rottentomatoes.com/m/primary_title',
#  'https://www.rottentomatoes.com/m/Foodfight',
#  'https://www.rottentomatoes.com/m/The_Overnight',
#  'https://www.rottentomatoes.com/m/The_Overnight',
#  'https://www.rottentomatoes.com/m/On_the_Road',
#  'https://www.rottentomatoes.com/m/On_the_Road',
#  'https://www.rottentomatoes.com/m/On_the_Road',
#  'https://www.rottentomatoes.com/m/The_Secret_Life_of_Walter_Mitty',
#  'https://www.rottentomatoes.com/m/A_Walk_Among_the_Tombstones',
#  'https://www.rottentomatoes.com/m/Jurassic_World',
#  'https://www.rottentomatoes.com/m/The_Rum_Diary',
#  'https://www.rottentomatoes.com/m/The_Three_Stooges',
#  'https://www.rottentomatoes.com/m/Andersons_Cross',
#  'https://www.rottentomatoes.com/m/Tangled',
#  'https://www.rottentomatoes.com/m/John_Carter',
#  'https://www.rottentomatoes.com/m/Action_Jackson',
#  'https://www.rottentomatoes.com/m/Dinner_for_Schmucks',
#  'https://www.rottentomatoes.com/m/The_A-Team',
# ...

# %%
#Collect the webpage we want tp scape 
#Will need to create a look to loop through each movie by title 
#Need to get rid of punctuaions in titles XXX
    
for title in new_list:
    R = requests.get('https://www.rottentomatoes.com/m/{}'.format(title))
    if R.status_code == 404:
        continue 
    elif R.status_code == 500:
        continue

# %%
R.status_code
# Out:
# 500

# %%
print(new_list[342])
# Out:
# Cars_2

# %%
type(titles)
# Out:
# list

# %%
#display what the url will be showing as 

print('https://www.rottentomatoes.com/m/{}'.format(titles[1]))
# Out:
# https://www.rottentomatoes.com/m/['Foodfight!']

# %%
new_list = []
for v in titles:
    new_list.append(v[0])


print('https://www.rottentomatoes.com/m/{}'.format(new_list[1]))
# Out:
# https://www.rottentomatoes.com/m/Foodfight

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-342120f4d75b> in <module>
#       1 for i in new_list:
# ----> 2     R = requests.get('https://www.rottentomatoes.com/m/{}'.format(new_list[i]))
#       3 R.status_code
#
# TypeError: list indices must be integers or slices, not str

# %%
R.status_code
# Out:
# 404

# %%
while i < len(new_list):
    R = requests.get('https://www.rottentomatoes.com/m/{}'.format(new_list[i]))
    i+=1

R.status_code
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-59b54ad5f1c6> in <module>
# ----> 1 while i < len(new_list):
#       2     R = requests.get('https://www.rottentomatoes.com/m/{}'.format(new_list[i]))
#       3     i+=1
#       4
#       5 R.status_code
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
reviews_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-130-9b9ace5501a7> in <module>
# ----> 1 reviews_df.head()
#
# NameError: name 'reviews_df' is not defined
